# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#       2 from langchain.prompts import ChatPromptTemplate
#
# ModuleNotFoundError: No module named 'langchain'

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\onedrive\desktop\mcqgen\env\lib\site-packages (from pandas) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting numpy>=1.20.3 (from pandas)
#   Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: six>=1.5 in d:\onedrive\desktop\mcqgen\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/10.8 MB 8.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/10.8 MB 7.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/10.8 MB 7.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.3/10.8 MB 7.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.8 MB 7.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 6.5 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/14.9 MB 7.6 MB/s eta 0:00:02
#    -------- ------------------------------- 3.1/14.9 MB 7.4 MB/s eta 0:00:02
#    ------------ --------------------------- 4.7/14.9 MB 7.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/14.9 MB 7.3 MB/s eta 0:00:02
#    --------------------- ------------------ 7.9/14.9 MB 7.3 MB/s eta 0:00:01
#    ------------------------- -------------- 9.4/14.9 MB 7.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.0/14.9 MB 7.2 MB/s eta 0:00:01
#    --------------------------------- ------ 12.6/14.9 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.9 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.9 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 6.8 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.24.4 pandas-2.0.3 pytz-2025.2 tzdata-2025.3

# %%
pip install openai
pip install langchain
# Out:
#   Cell In[5], line 1
#     pip install openai
#         ^
# SyntaxError: invalid syntax
